# %% [markdown]
# TODO: Click on the badge above, then `Copy to Drive` before continuing.

# %% [markdown]
# TODO: double click and replace this text with your name

# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://githubtocolab.com/allegheny-college-cmpsc-105-spring-2026/dataDistortion-starter/blob/main/data_distortion.ipynb)

# %% [markdown]
# # Data Distortion Lab
#
# ---
#
# In this lab, you will explore hourly temperature normals from Meadville, PA and Juneau, AK to make several visual comparisons.
#
# Temperature normals are temperatures that the NOAA (National Oceanic and Atmospheric Administration) publishes for many different locations in the United States that are considered normal over the course of a year. In this lab, you have access to normals for every hour in a template year for Meadville, PA and Juneau, AK.
#
# Code is provided to load in the datasets into Pandas dataframes. The dataframe for the Meadville data is in a variable called `dfm`. The dataframe for the Juneau data is in a variable called `dfj`. The column names for both dataframes are `'INDEX', 'STATION', 'NAME', 'LATITUDE', 'LONGITUDE', 'ELEVATION', 'DATE', 'month', 'day', 'hour', 'HLY-TEMP-NORMAL'`. The raw data can be viewed here:
#
# - [Meadville, PA Normals](https://raw.githubusercontent.com/allegheny-college-cmpsc-105-spring-2026/dataDistortion-starter/blob/main/data/data-distortion-noaa-2006-2020-USW00004843.csv)
# - [Juneau, AK Normals](https://raw.githubusercontent.com/allegheny-college-cmpsc-105-spring-2026/dataDistortion-starter/blob/main/data/data-distortion-noaa-2006-2020-USW00025309.csv)
#
# ## Goals
#
# The goals for your exploration are to make several visual comparisons.
#
# 1. Visually show a comparison of temperatures in Meadville and Juneau in the month of January.
# 2. Distort the visuals so that it looks like the colder place is actually warmer.
# 3. Explore the data to find the month that is visually the **most** different between Meadville and Juneau
# 4. Visually show a comparison of temperatures for daytime and nighttime hours for Meadville and Juneau on September 1.
#
#
# This lab should be completed during the lab meeting time, but modifations may be made until the official deadline of 4:15pm on Feb 3rd.
#
# Don't forget to answer all `T O D O` markers and to remove the markers.
#
# ## Learning Outcomes
#
# By completing this lab you will
#
# - explore two dataset by maniputing views into the data
# - write a report in a markdown cell
# - modify a url to your work to make it accessible
# - update a GitHub Repository
# - check gatorgrade in GitHub Actions
#
# ## Reminders
#
# - If needed, one of four available automatic extension tokens can be applied by using the form on found on the course syllabys.
# - If you have a question, post in the 105 Discord channel.
# - Refer to previous materials to learn how to use Notebooks in Google Colab, make your work accessible, submit, and check your work.
#
# ## Saving Your Work
#
# Saving your work and making it accessible is a required part of all labs.
#
# ### Accessability Part 1
#
# Update the Colab file name to be `data_display.ipynb`.
#
# Make sure that all cells have been executed and are SHOWING their outputs.
#
# In order to make this file accessible you will have to edit the very top badge that looks like this: ![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg).
#
# - Double click next to the top badge to take a look at the urls inside.
# - You should see this: `https://githubtocolab.com/allegheny-college-cmpsc-105-spring-2026/data-distortion-starter/blob/main/data_distortion.ipynb)`
# - Change the word `starter` to your github user name.
#
# ### Saving
#
# I would recommend a workflow of `Copy to Drive --> editing/running/testing --> downloading`. You should have already hit `Copy to Drive`, but if you haven't, then please do so now. Then go ahead and download the file from the menu at the top of the Colab interface. File > Download > Download ipynb
#
# ### Accessibility Part 2
#
# If you are satisfied with your work, you can now upload the downloaded file to your GitHub repo!
#
# - If you know what `git` is, you may use it to upload the file, otherwise do the next method instead.
# - Use GitHub to upload the file.
#   - Next to the green code button in GitHub, you will see an `add file` button. Click that, then choose the downloaded notebook from your computer.
#
# ## Checking Your Work
#
# ### Check your file output
#
# Once your file is uploaded, please open it on GitHub. All the outputs and plots should be showing. If they are not showing, this means that not all code cells were executed before you downloaded your file.
#
# ### Check your badge
#
# Check that the badge is working by clicking on it. It should take you into Google Colab with **your** file (not the starter file).
#
# ### Check GitHub Actions
#
# Back in GitHub, go to the Actions tab. Click on the top Action to see a report about your T O D Os. If the T O D Os have been done and deleted, then the actions will show that gatorgrade reports 100%. This is not your grade, but it is a good indication that you did not forget to do something.
#
# If you see remaining T O D Os, then you may want to edit and update your file.

# %% [markdown]
# ## Getting Started

# %%
# TODO: Run this code cell that makes pre-existing tools available for data exploration

import pandas as pd
import matplotlib.pyplot as plt

# %%
# TODO: Run this code cell that creates a pandas dataframe for Meadville

dfm = pd.read_csv(
    'https://raw.githubusercontent.com/allegheny-college-cmpsc-105-spring-2026/dataDistortion-starter/main/data/data-distortion-noaa-2006-2020-USW00004843.csv',
    sep=',',
    names = ['INDEX', 'STATION', 'NAME', 'LATITUDE', 'LONGITUDE', 'ELEVATION',
       'DATE', 'month', 'day', 'hour', 'HLY-TEMP-NORMAL'],
    skiprows=1
)

print(dfm.head()) # Display the first few rows of the DataFrame

# %%
# TODO: Run this code cell that creates a pandas dataframe for Juneau

dfj = pd.read_csv(
    'https://raw.githubusercontent.com/allegheny-college-cmpsc-105-spring-2026/dataDistortion-starter/main/data/data-distortion-noaa-2006-2020-USW00025309.csv',
    sep=',',
    names = ['INDEX', 'STATION', 'NAME', 'LATITUDE', 'LONGITUDE', 'ELEVATION',
       'DATE', 'month', 'day', 'hour', 'HLY-TEMP-NORMAL'],
    skiprows=1
)

print(dfj.head()) # Display the first few rows of the DataFrame

# %% [markdown]
# ## Next Steps
#
# Please answer these questions before continuing.
#
# - TODO: How many rows of data are there for dfm and dfj?
# - TODO: What does each row represent?
# - TODO: How many columns of data are there for dfm and dfj?
# - TODO: Which columns represent some measure of time?
# - TODO: Which columns represent some measure of location?
# - TODO: Which columns represent some measure of temperature?
# - TODO: Explain if the rows and columns match or don't match between dfm and dfj.
# - TODO: What does this mean for making visual comparisons?

# %%
# Assume dfs are already created in the previous code cells

# TODO: Run this code cell that creates two sublots within one figure canvas
# TODO: Looking at the code, add an appropriate titles to each subplot identifying the location

# clear out memory (doesn't impact the visualization, but keeps the computer happy)
plt.close('all')

# make a blank canvas
plt.figure(figsize=(12, 4))
plt.suptitle('FIGURE 1')

# subplot 1
plt.subplot(1,2,1)
plt.title('TODO')
plt.plot(dfm['INDEX'], dfm['HLY-TEMP-NORMAL'], '*-')
plt.xlabel('Time Index (hours)')
plt.ylabel('Normal Temperature (F)')

# subplot 2
plt.subplot(1,2,2)
plt.title('TODO')
plt.plot(dfj['INDEX'], dfj['HLY-TEMP-NORMAL'], '*-')
plt.xlabel('Time Index (hours)')
plt.ylabel('Normal Temperature (F)')

# reveal everything
plt.show()

# %% [markdown]
# ## Make a valid comparison of temperatures in Meadville and Juneau in the month of January

# %%
# Assume dfs are already created in the previous code cells

# TODO: Run this code cell that creates two suplots within one figure canvas
# TODO: Looking at the code, add an appropriate subtitle to each plot identifying the location
# TODO: Add x axis labels with units
# TODO: Add y axis labels with units
# TODO: Change and/or add limits to focus in on January
# TODO: Ensure that you are making a valid visual comparison that is not misleading!

# Optional TODO: change the xtick_hopsize as needed for more/less xtick labels
xtick_hopsize = 72 # hours

# clear out memory (doesn't impact the visualization, but keeps the computer happy)
plt.close('all')

# make a blank canvas
plt.figure(figsize=(12, 4))
plt.suptitle('FIGURE 1')

# subplot 1
plt.subplot(1,2,1)
plt.title('TODO')
plt.plot(dfm['INDEX'], dfm['HLY-TEMP-NORMAL'], '*-')
plt.xticks(dfm['INDEX'][::xtick_hopsize], dfm['DATE'][::xtick_hopsize], rotation=90)
plt.xlim(600, 700)

# subplot 2
plt.subplot(1,2,2)
plt.title('TODO')
plt.plot(dfj['INDEX'], dfj['HLY-TEMP-NORMAL'], '*-')
plt.xticks(dfj['INDEX'][::xtick_hopsize], dfj['DATE'][::xtick_hopsize], rotation=90)
plt.xlim(900,950)

# reveal everything
plt.show()

# %% [markdown]
# - TODO: What are the time limits used for January?
# - TODO: Which location has warmer normals for January?
# - TODO: Describe the normals you see in each case.
# - TODO: What did you do to make the visual comparison "valid" and not misleading?

# %% [markdown]
# ## Make a visually misleading comparison of temperatures in Meadville and Juneau in the month of January

# %%
# Assume dfs are already created in the previous code cells

# TODO: Copy the code from above and modify it to make a misleading comparison
# TODO: Specifically, make visual changes that will portray the colder location as looking warmer in January

# %% [markdown]
# - TODO: What did you do to make the visual comparison misleading?
# - TODO: What could someone conclude by looking at the misleading visualization?

# %% [markdown]
# ## Visually show a comparison of temperatures for daytime and nighttime hours for Meadville and Juneau on September 1

# %%
# Assume dfs are already created in the previous code cells

# TODO: Run the provided code, then make adjustments as needed
# TODO: Specifically, modify the code to make it focus in on the daytime and nightime hours of Sept 1 for both Meadville and Juneau
# TODO: Add x axis labels with units
# TODO: Add y axis labels with units


# TODO: change the xtick_hopsize as needed for more/less xtick labels
xtick_hopsize = 100 # hours

# clear out memory (doesn't impact the visualization, but keeps the computer happy)
plt.close('all')

# make a blank canvas
plt.figure(figsize=(12, 4))

# subplot 1
plt.subplot(1,2,1)
plt.title("Daytime Normals on Sept 1")
plt.plot(dfm['INDEX'], dfm['HLY-TEMP-NORMAL'], '*-') # layer 1 from dfm
plt.plot(dfj['INDEX'], dfj['HLY-TEMP-NORMAL'], '*-') # layer 2 from dfj
plt.legend(['TODO: change the legend label here for layer 1', 'TODO: change the other legend label here for layer 2'])
plt.xticks(dfm['INDEX'][::xtick_hopsize], dfm['DATE'][::xtick_hopsize], rotation=90)
plt.xlim(600, 624)

# subplot 2
plt.subplot(1,2,2)
plt.title("Nighttime Normals on Sept 1")
plt.plot(dfm['INDEX'], dfm['HLY-TEMP-NORMAL'], '*-') # layer 1 from dfm
plt.plot(dfj['INDEX'], dfj['HLY-TEMP-NORMAL'], '*-') # layer 2 from dfj
plt.legend(['TODO: change the legend label here for layer 1', 'TODO: change the other legend label here for layer 2'])
plt.xticks(dfj['INDEX'][::xtick_hopsize], dfj['DATE'][::xtick_hopsize], rotation=90)
plt.xlim(900,924)

# reveal everything
plt.show()

# %% [markdown]
# - What new features of plotting in matplotlib do you notice above?
# - In words only (not code), how might you change the visualization to be more readable?

# %% [markdown]
# ## Explore the data to find the month that is visually the most **similar** and most **different** between Meadville and Juneau

# %%
# Assume dfs are already created in the previous code cells

# TODO: Borrow code from any cells above and modify it to show the months that are most and least similar between Meadville and Juneau
# TODO: Specifically, make the left panel layer the normals from Meadville and Juneau in the most similar month
# TODO: Make the right panel layer the normals from Meadville and Juneau in the most different month

# %% [markdown]
# - TODO: What month has normals that are the most similar between Meadville and Juneau?
# - TODO: What month has normals that are the most different between Meadville and Juneau?
# - TODO: Describe those normals
# - TODO: Now continue on below to the markdown report, which is like a short write up presenting what you did in this lab, what you found, what you would like to explore further, and technical skillled learned.

# %% [markdown]
# ## Report
#
# ### What this was lab about
#
# TODO: Briefly summarize what this lab was about and what you did at a high level.
#
# ### Methods
#
# TODO: Breifly talk about the tools you used to explore the data and any specific functions that helped reveal the patterns.
#
# ### What was found
#
# TODO: Breifly restate what you found out about temerature normals by exploring the data. Please refer to the figures you made above. For example, "As shown in figure 1, the temperature normals go from abc to xyz course of a year in Meadville."
#
# ### Future directions
#
# TODO: Breifly state what could be explored within the data in the future, building on what you already did.

# %% [markdown]
# Data Sources:
# - https://noaanormals.blob.core.windows.net/climate-normals/normals-hourly/2006-2020/access/USW00004843.csv
# - https://noaanormals.blob.core.windows.net/climate-normals/normals-hourly/2006-2020/access/USW00025309.csv
# - https://www.ncei.noaa.gov/products/paleoclimatology
# - https://www.ncei.noaa.gov/maps/normals/
# - https://www.ncei.noaa.gov/data/normals-annualseasonal/2006-2020/access/
# - https://microsoft.github.io/AIforEarthDataSets/data/noaa-climatenormals.html
